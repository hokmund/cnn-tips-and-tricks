# %%
import pandas as pd
import numpy as np

from file_utils import count_images
from demo_utils import plot_class_distribution, show_image
# %matplotlib inline

# %% [markdown]
# iMaterialist Challenge 2018 - https://www.kaggle.com/c/imaterialist-challenge-furniture-2018/data
#
# Link to download prepared dataset - http://tiny.cc/4flryy

# %%
source_dir = 'data'
train_dir = 'train'
val_dir = 'validation'
test_dir = 'test'

# %%
train_classes = count_images(train_dir)
val_classes = count_images(val_dir)
test_classes = count_images(test_dir)

print(f'Train images: {np.sum(train_classes)}')
print(f'Validation images: {np.sum(val_classes)}')
print(f'Test images: {np.sum(test_classes)}')
# Out:
# Train images: 37184
# Validation images: 12800
# Test images: 25600

# %%
plot_class_distribution(train_classes)

# %%
plot_class_distribution(val_classes)

# %%
plot_class_distribution(test_classes)

# %%
print(f'Min class {train_classes.idxmin()} with {train_classes.min()} samples')
print(f'Max class {train_classes.idxmax()} with {train_classes.max()} samples')
# Out:
# Min class 83 with 67 samples
# Max class 114 with 361 samples

# %% [markdown]
# **Samples** which are displayed on your computer **might be different** (it depends on OS).

# %%
image_id = 4 # chosen by fair dice roll; guaranteed to be random. (https://xkcd.com/221/)

class_id = 23
show_image(train_dir, class_id, image_id)

# %%
class_id = 35
show_image(train_dir, class_id, image_id)

# %%
class_id = 42
show_image(train_dir, class_id, image_id)

# %%
class_id = 106
show_image(train_dir, class_id, image_id)
